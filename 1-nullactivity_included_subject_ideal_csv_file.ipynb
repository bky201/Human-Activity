# %% [markdown]
# # Converting from .log file to csv file

# %%
import glob

# %%
dataset_path = r'D:\projec\Advanced pro1\sub'

# %%
f = glob.glob(dataset_path +'\*.log')

# %%
import numpy as np
import pandas as pd
import os

# %%
columns = ['ts1','ts2','RLA:ACC:X', 'RLA:ACC:Y', 'RLA:ACC:Z', 'RLA:GYR:X', 'RLA:GYR:Y', 'RLA:GYR:Z', 'RLA:MAG:X', 'RLA:MAG:Y', 'RLA:MAG:Z', 'RLA:QUAT:1', 'RLA:QUAT:2', 'RLA:QUAT:3', 'RLA:QUAT:4',
'RUA:ACC:X', 'RUA:ACC:Y', 'RUA:ACC:Z', 'RUA:GYR:X', 'RUA:GYR:Y', 'RUA:GYR:Z', 'RUA:MAG:X', 'RUA:MAG:Y', 'RUA:MAG:Z', 'RUA:QUAT:1', 'RUA:QUAT:2', 'RUA:QUAT:3', 'RUA:QUAT:4',
'BACK:ACC:X', 'BACK:ACC:Y', 'BACK:ACC:Z', 'BACK:GYR:X', 'BACK:GYR:Y', 'BACK:GYR:Z', 'BACK:MAG:X', 'BACK:MAG:Y', 'BACK:MAG:Z', 'BACK:QUAT:1', 'BACK:QUAT:2', 'BACK:QUAT:3', 'BACK:QUAT:4',
'LUA:ACC:X', 'LUA:ACC:Y', 'LUA:ACC:Z', 'LUA:GYR:X', 'LUA:GYR:Y', 'LUA:GYR:Z', 'LUA:MAG:X', 'LUA:MAG:Y', 'LUA:MAG:Z', 'LUA:QUAT:1', 'LUA:QUAT:2', 'LUA:QUAT:3', 'LUA:QUAT:4',
'LLA:ACC:X', 'LLA:ACC:Y', 'LLA:ACC:Z', 'LLA:GYR:X', 'LLA:GYR:Y', 'LLA:GYR:Z', 'LLA:MAG:X', 'LLA:MAG:Y', 'LLA:MAG:Z', 'LLA:QUAT:1', 'LLA:QUAT:2', 'LLA:QUAT:3', 'LLA:QUAT:4',
'RC:ACC:X', 'RC:ACC:Y', 'RC:ACC:Z', 'RC:GYR:X', 'RC:GYR:Y', 'RC:GYR:Z', 'RC:MAG:X', 'RC:MAG:Y', 'RC:MAG:Z', 'RC:QUAT:1', 'RC:QUAT:2', 'RC:QUAT:3', 'RC:QUAT:4',
'RT:ACC:X', 'RT:ACC:Y', 'RT:ACC:Z', 'RT:GYR:X', 'RT:GYR:Y', 'RT:GYR:Z', 'RT:MAG:X', 'RT:MAG:Y', 'RT:MAG:Z', 'RT:QUAT:1', 'RT:QUAT:2', 'RT:QUAT:3', 'RT:QUAT:4',
'LT:ACC:X', 'LT:ACC:Y', 'LT:ACC:Z', 'LT:GYR:X', 'LT:GYR:Y', 'LT:GYR:Z', 'LT:MAG:X', 'LT:MAG:Y', 'LT:MAG:Z', 'LT:QUAT:1', 'LT:QUAT:2', 'LT:QUAT:3', 'LT:QUAT:4',
'LC:ACC:X', 'LC:ACC:Y', 'LC:ACC:Z', 'LC:GYR:X', 'LC:GYR:Y', 'LC:GYR:Z', 'LC:MAG:X', 'LC:MAG:Y', 'LC:MAG:Z', 'LC:QUAT:1', 'LC:QUAT:2', 'LC:QUAT:3', 'LC:QUAT:4','targets']

# %%
parent_dir = r'D:\projec\proj'
path1 = os.path.join(parent_dir, "data_ideal_null")

# %%
os.mkdir(path1)

# %%
for subject in range(1, 18):
    file_path = dataset_path + '\subject{0}_ideal.log'.format(subject)
    file = pd.read_csv(file_path,header=None, sep='\t',names=columns)
    for column in columns:
        file[column] = file[column].astype('float')
    file['targets'] = file['targets'].astype('int')
    
    file.to_csv(r"D:\projec\proj\data_ideal_null\subject{0}_ideal.csv".format(subject),header=None,sep='\t', index= False)

# %%
file = pd.read_csv(r"D:\projec\proj\data_ideal_null\subject1_ideal.csv",header=None, sep='\t',names=columns)

# %%
file
# Out:
#            ts1       ts2  RLA:ACC:X  RLA:ACC:Y  RLA:ACC:Z  RLA:GYR:X  \
# 0          0.0   20000.0    -9.2149     1.6078    4.10230   0.008919
# 1          0.0   40000.0    -8.6113     1.5618    3.72490   0.024428
# 2          0.0   60000.0    -8.8804     2.2894    3.89920   0.005306
# 3          0.0   80000.0    -8.9027     1.5766    3.97790  -0.002000
# 4          0.0  100000.0    -8.7353     1.6078    3.86050   0.003471
# ...        ...       ...        ...        ...        ...        ...
# 179032  2259.0  360000.0    -9.3234     3.2436    0.18500   0.005184
# 179033  2259.0  380000.0    -9.4068     3.4112    0.12702   0.043406
# 179034  2259.0  400000.0    -9.4585     3.6980    0.36775  -0.000425
# 179035  2259.0  420000.0    -9.5900     3.7474    0.27538   0.207390
# 179036  2259.0  440000.0    -9.3798     3.7585   -0.75353   0.529930
#
#         RLA:GYR:Y  RLA:GYR:Z  RLA:MAG:X  RLA:MAG:Y  ...  LC:GYR:Y  LC:GYR:Z  \
# 0        0.005707   0.015156    1.24760  -0.034121  ...  0.005075 -0.004637
# 1       -0.002711  -0.020531    1.24980  -0.025369  ...  0.006886 -0.004597
# 2       -0.023138   0.029458    1.25090  -0.025673  ...  0.003375 -0.011827
# 3       -0.013688  -0.013656    1.24690  -0.032399  ...  0.003363 -0.008280
# 4       -0.015327  -0.023457    1.24690  -0.031557  ...  0.003186  0.006253
# ...           ...        ...        ...        ...  ...       ...       ...
# 179032   0.061797  -0.010332    0.84479   0.137500  ...  0.016843 -0.017134
# 179033   0.118670   0.044932    0.84330   0.136230  ...  0.025876 -0.015317
# 179034   0.164490   0.099591    0.84559   0.135170  ...  0.020454 -0.016237
# 179035   0.228260   0.230530    0.84681   0.130860  ...  0.011289 -0.015249
# 179036   0.417960   0.371010    0.85061   0.121930  ... -0.000259 -0.036989
#
#         LC:MAG:X  LC:MAG:Y  LC:MAG:Z  LC:QUAT:1  LC:QUAT:2  LC:QUAT:3  \
# 0        0.77288   0.18375  -0.12589   0.079751    0.68380    0.19458
# 1        0.77179   0.18946  -0.13054   0.079934    0.68380    0.19448
# 2        0.77207   0.18821  -0.12990   0.084122    0.68260    0.19875
# 3        0.77369   0.18514  -0.12733   0.084993    0.68214    0.19804
# 4        0.77369   0.18540  -0.12640   0.085095    0.68218    0.19807
# ...          ...       ...       ...        ...        ...        ...
# 179032   0.69784   0.39837  -0.33706   0.478640    0.50215    0.32154
# 179033   0.69770   0.39809  -0.33734   0.478830    0.50194    0.32216
# 179034   0.69907   0.39987  -0.33556   0.479010    0.50172    0.32270
# 179035   0.69907   0.39960  -0.33624   0.478980    0.50167    0.32292
# 179036   0.69797   0.40060  -0.33729   0.478720    0.50160    0.32300
#
#         LC:QUAT:4  targets
# 0        -0.69871        0
# 1        -0.69872        0
# 2        -0.69820        0
# 3        -0.69874        0
# 4        -0.69868        0
# ...           ...      ...
# 179032   -0.64448        0
# 179033   -0.64420        0
# 179034   -0.64396        0
# 179035   -0.64392        0
# 179036   -0.64412        0
#
# [179037 rows x 120 columns]
