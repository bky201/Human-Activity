# %% [markdown]
# # Converting from .log file to csv file

# %%
import glob

# %%
dataset_path = r'D:\projec\Advanced pro1\sub'

# %%
f = glob.glob(dataset_path +'\*.log')

# %%
import numpy as np
import pandas as pd
import os

# %%
columns = ['ts1','ts2','RLA:ACC:X', 'RLA:ACC:Y', 'RLA:ACC:Z', 'RLA:GYR:X', 'RLA:GYR:Y', 'RLA:GYR:Z', 'RLA:MAG:X', 'RLA:MAG:Y', 'RLA:MAG:Z', 'RLA:QUAT:1', 'RLA:QUAT:2', 'RLA:QUAT:3', 'RLA:QUAT:4',
'RUA:ACC:X', 'RUA:ACC:Y', 'RUA:ACC:Z', 'RUA:GYR:X', 'RUA:GYR:Y', 'RUA:GYR:Z', 'RUA:MAG:X', 'RUA:MAG:Y', 'RUA:MAG:Z', 'RUA:QUAT:1', 'RUA:QUAT:2', 'RUA:QUAT:3', 'RUA:QUAT:4',
'BACK:ACC:X', 'BACK:ACC:Y', 'BACK:ACC:Z', 'BACK:GYR:X', 'BACK:GYR:Y', 'BACK:GYR:Z', 'BACK:MAG:X', 'BACK:MAG:Y', 'BACK:MAG:Z', 'BACK:QUAT:1', 'BACK:QUAT:2', 'BACK:QUAT:3', 'BACK:QUAT:4',
'LUA:ACC:X', 'LUA:ACC:Y', 'LUA:ACC:Z', 'LUA:GYR:X', 'LUA:GYR:Y', 'LUA:GYR:Z', 'LUA:MAG:X', 'LUA:MAG:Y', 'LUA:MAG:Z', 'LUA:QUAT:1', 'LUA:QUAT:2', 'LUA:QUAT:3', 'LUA:QUAT:4',
'LLA:ACC:X', 'LLA:ACC:Y', 'LLA:ACC:Z', 'LLA:GYR:X', 'LLA:GYR:Y', 'LLA:GYR:Z', 'LLA:MAG:X', 'LLA:MAG:Y', 'LLA:MAG:Z', 'LLA:QUAT:1', 'LLA:QUAT:2', 'LLA:QUAT:3', 'LLA:QUAT:4',
'RC:ACC:X', 'RC:ACC:Y', 'RC:ACC:Z', 'RC:GYR:X', 'RC:GYR:Y', 'RC:GYR:Z', 'RC:MAG:X', 'RC:MAG:Y', 'RC:MAG:Z', 'RC:QUAT:1', 'RC:QUAT:2', 'RC:QUAT:3', 'RC:QUAT:4',
'RT:ACC:X', 'RT:ACC:Y', 'RT:ACC:Z', 'RT:GYR:X', 'RT:GYR:Y', 'RT:GYR:Z', 'RT:MAG:X', 'RT:MAG:Y', 'RT:MAG:Z', 'RT:QUAT:1', 'RT:QUAT:2', 'RT:QUAT:3', 'RT:QUAT:4',
'LT:ACC:X', 'LT:ACC:Y', 'LT:ACC:Z', 'LT:GYR:X', 'LT:GYR:Y', 'LT:GYR:Z', 'LT:MAG:X', 'LT:MAG:Y', 'LT:MAG:Z', 'LT:QUAT:1', 'LT:QUAT:2', 'LT:QUAT:3', 'LT:QUAT:4',
'LC:ACC:X', 'LC:ACC:Y', 'LC:ACC:Z', 'LC:GYR:X', 'LC:GYR:Y', 'LC:GYR:Z', 'LC:MAG:X', 'LC:MAG:Y', 'LC:MAG:Z', 'LC:QUAT:1', 'LC:QUAT:2', 'LC:QUAT:3', 'LC:QUAT:4','targets']

# %%
parent_dir = r'D:\projec\proj'
path1 = os.path.join(parent_dir, "data_mutual6")

# %%
os.mkdir(path1)

# %%
List = [2,5,15]

# %%
for subject in List:
    file_path = dataset_path + '\subject{0}_mutual6.log'.format(subject)
    file = pd.read_csv(file_path,header=None, sep='\t',names=columns)
    for column in columns:
        file[column] = file[column].astype('float')
    file['targets'] = file['targets'].astype('int')
    
    file.to_csv(r"D:\projec\proj\data_mutual6\subject{0}_mutual6.csv".format(subject),header=None,sep='\t', index= False)

# %%
file = pd.read_csv(r"D:\projec\proj\data_mutual6\subject2_mutual6.csv",header=None, sep='\t',names=columns)

# %%
file
# Out:
#            ts1       ts2  RLA:ACC:X  RLA:ACC:Y  RLA:ACC:Z  RLA:GYR:X  \
# 0          0.0   20000.0    -9.9166     1.8110   -0.55257   1.113300
# 1          0.0   40000.0    -9.5318     1.7147   -1.01550   1.026700
# 2          0.0   60000.0    -9.3603     2.0633   -1.47440   0.939880
# 3          0.0   80000.0    -9.7618     2.4831   -1.45840   0.737180
# 4          0.0   20000.0    -7.9194     1.3636    5.00890   0.206300
# ...        ...       ...        ...        ...        ...        ...
# 193356  3867.0   40000.0    -7.6998     2.7363    4.40690  -0.372180
# 193357  3867.0   60000.0    -7.9448     2.9052    4.92480  -0.228380
# 193358  3867.0   80000.0    -7.9571     2.7495    5.12440  -0.092729
# 193359  3867.0  100000.0    -7.8845     2.9598    5.45120   0.088919
# 193360  3867.0  120000.0    -8.2483     3.5831    6.07290   0.075436
#
#         RLA:GYR:Y  RLA:GYR:Z  RLA:MAG:X  RLA:MAG:Y  ...  LC:GYR:Y  LC:GYR:Z  \
# 0       -0.978360   0.105630    0.80874   -0.16783  ...  1.319100 -2.564000
# 1       -0.938830   0.118660    0.80155   -0.16855  ...  1.245900 -2.743000
# 2       -0.870620   0.184880    0.79662   -0.17158  ...  1.123800 -2.852400
# 3       -0.818230   0.230190    0.78983   -0.17714  ...  0.970330 -2.921200
# 4       -0.200290   0.180910    0.62292   -0.32311  ...  0.019039  0.018538
# ...           ...        ...        ...        ...  ...       ...       ...
# 193356   0.168970  -0.030260    0.57525   -0.36123  ... -0.015624  0.006275
# 193357   0.150390  -0.037462    0.57559   -0.36091  ... -0.015556 -0.006094
# 193358   0.108660  -0.060952    0.57715   -0.36105  ...  0.006261 -0.009518
# 193359   0.066540  -0.059731    0.57882   -0.35862  ... -0.001601 -0.006912
# 193360  -0.038274  -0.064611    0.57838   -0.35776  ...  0.008925 -0.023629
#
#         LC:MAG:X  LC:MAG:Y  LC:MAG:Z  LC:QUAT:1  LC:QUAT:2  LC:QUAT:3  \
# 0        0.99505 -0.051683  0.419220    0.75274   -0.36955    0.53533
# 1        0.95320  0.047711  0.420170    0.75305   -0.37575    0.53549
# 2        0.90689  0.113450  0.407010    0.75594   -0.37278    0.53739
# 3        0.86525  0.160380  0.388180    0.76163   -0.34769    0.54679
# 4        0.81875  0.193840  0.178720    0.47674    0.43302    0.63609
# ...          ...       ...       ...        ...        ...        ...
# 193356   0.77206 -0.054494 -0.024859    0.12050    0.65635    0.20793
# 193357   0.77271 -0.054894 -0.025092    0.12051    0.65619    0.20781
# 193358   0.77381 -0.054684 -0.024501    0.12058    0.65616    0.20777
# 193359   0.77350 -0.055163 -0.025317    0.12067    0.65608    0.20780
# 193360   0.77301 -0.055068 -0.024549    0.12074    0.65602    0.20798
#
#         LC:QUAT:4  targets
# 0        0.101180        0
# 1        0.070624        0
# 2        0.028370        0
# 3        0.008105        0
# 4       -0.424970        0
# ...           ...      ...
# 193356  -0.715160        0
# 193357  -0.715340        0
# 193358  -0.715360        0
# 193359  -0.715410        0
# 193360  -0.715400        0
#
# [193361 rows x 120 columns]
