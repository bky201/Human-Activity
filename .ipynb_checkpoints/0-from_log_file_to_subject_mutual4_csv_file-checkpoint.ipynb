# %% [markdown]
# # Converting from .log file to csv file

# %%
import glob

# %%
dataset_path = r'D:\projec\Advanced pro1\sub'

# %%
f = glob.glob(dataset_path +'\*.log')

# %%
import numpy as np
import pandas as pd
import os

# %%
columns = ['ts1','ts2','RLA:ACC:X', 'RLA:ACC:Y', 'RLA:ACC:Z', 'RLA:GYR:X', 'RLA:GYR:Y', 'RLA:GYR:Z', 'RLA:MAG:X', 'RLA:MAG:Y', 'RLA:MAG:Z', 'RLA:QUAT:1', 'RLA:QUAT:2', 'RLA:QUAT:3', 'RLA:QUAT:4',
'RUA:ACC:X', 'RUA:ACC:Y', 'RUA:ACC:Z', 'RUA:GYR:X', 'RUA:GYR:Y', 'RUA:GYR:Z', 'RUA:MAG:X', 'RUA:MAG:Y', 'RUA:MAG:Z', 'RUA:QUAT:1', 'RUA:QUAT:2', 'RUA:QUAT:3', 'RUA:QUAT:4',
'BACK:ACC:X', 'BACK:ACC:Y', 'BACK:ACC:Z', 'BACK:GYR:X', 'BACK:GYR:Y', 'BACK:GYR:Z', 'BACK:MAG:X', 'BACK:MAG:Y', 'BACK:MAG:Z', 'BACK:QUAT:1', 'BACK:QUAT:2', 'BACK:QUAT:3', 'BACK:QUAT:4',
'LUA:ACC:X', 'LUA:ACC:Y', 'LUA:ACC:Z', 'LUA:GYR:X', 'LUA:GYR:Y', 'LUA:GYR:Z', 'LUA:MAG:X', 'LUA:MAG:Y', 'LUA:MAG:Z', 'LUA:QUAT:1', 'LUA:QUAT:2', 'LUA:QUAT:3', 'LUA:QUAT:4',
'LLA:ACC:X', 'LLA:ACC:Y', 'LLA:ACC:Z', 'LLA:GYR:X', 'LLA:GYR:Y', 'LLA:GYR:Z', 'LLA:MAG:X', 'LLA:MAG:Y', 'LLA:MAG:Z', 'LLA:QUAT:1', 'LLA:QUAT:2', 'LLA:QUAT:3', 'LLA:QUAT:4',
'RC:ACC:X', 'RC:ACC:Y', 'RC:ACC:Z', 'RC:GYR:X', 'RC:GYR:Y', 'RC:GYR:Z', 'RC:MAG:X', 'RC:MAG:Y', 'RC:MAG:Z', 'RC:QUAT:1', 'RC:QUAT:2', 'RC:QUAT:3', 'RC:QUAT:4',
'RT:ACC:X', 'RT:ACC:Y', 'RT:ACC:Z', 'RT:GYR:X', 'RT:GYR:Y', 'RT:GYR:Z', 'RT:MAG:X', 'RT:MAG:Y', 'RT:MAG:Z', 'RT:QUAT:1', 'RT:QUAT:2', 'RT:QUAT:3', 'RT:QUAT:4',
'LT:ACC:X', 'LT:ACC:Y', 'LT:ACC:Z', 'LT:GYR:X', 'LT:GYR:Y', 'LT:GYR:Z', 'LT:MAG:X', 'LT:MAG:Y', 'LT:MAG:Z', 'LT:QUAT:1', 'LT:QUAT:2', 'LT:QUAT:3', 'LT:QUAT:4',
'LC:ACC:X', 'LC:ACC:Y', 'LC:ACC:Z', 'LC:GYR:X', 'LC:GYR:Y', 'LC:GYR:Z', 'LC:MAG:X', 'LC:MAG:Y', 'LC:MAG:Z', 'LC:QUAT:1', 'LC:QUAT:2', 'LC:QUAT:3', 'LC:QUAT:4','targets']

# %%
parent_dir = r'D:\projec\proj'
path1 = os.path.join(parent_dir, "data_mutual4")

# %%
os.mkdir(path1)

# %%
List = [2,5,15]

# %%
for subject in List:
    file_path = dataset_path + '\subject{0}_mutual4.log'.format(subject)
    file = pd.read_csv(file_path,header=None, sep='\t',names=columns)
    for column in columns:
        file[column] = file[column].astype('float')
    file['targets'] = file['targets'].astype('int')
    
    file.to_csv(r"D:\projec\proj\data_mutual4\subject{0}_mutual4.csv".format(subject),header=None,sep='\t', index= False)

# %%
file = pd.read_csv(r"D:\projec\proj\data_mutual4\subject2_mutual4.csv",header=None, sep='\t',names=columns)

# %%
file
# Out:
#           ts1       ts2  RLA:ACC:X  RLA:ACC:Y  RLA:ACC:Z  RLA:GYR:X  \
# 0         0.0   20000.0    -6.6324     3.1127     6.8082  -0.124620
# 1         0.0   40000.0    -6.7900     2.7849     6.6907  -0.278250
# 2         0.0   60000.0    -6.9116     2.8166     6.5619  -0.223990
# 3         0.0   20000.0    -4.7509     6.1399     6.0274  -0.008450
# 4         0.0   40000.0    -4.7737     5.9708     6.0690  -0.028349
# ...       ...       ...        ...        ...        ...        ...
# 190407  767.0  980000.0     2.0198     1.3360     9.4866  -0.084945
# 190408  768.0       0.0     2.3933     1.1386    10.4340  -0.075872
# 190409  768.0   20000.0     2.4333     1.0367    10.5550   0.053910
# 190410  768.0   40000.0     2.6508     1.5550    10.3520   0.091970
# 190411  768.0   60000.0     2.7518     1.7010     9.5136   0.021967
#
#         RLA:GYR:Y  RLA:GYR:Z  RLA:MAG:X  RLA:MAG:Y  ...  LC:GYR:Y  LC:GYR:Z  \
# 0        0.007565  -0.049080    0.56646  -0.099561  ...  0.006533 -0.004929
# 1        0.028163  -0.063531    0.56194  -0.092043  ...  0.008282 -0.006687
# 2        0.025034  -0.063373    0.56134  -0.088951  ...  0.008209  0.012742
# 3       -0.012188   0.020988    0.48334  -0.562780  ...  0.009607 -0.008547
# 4       -0.019502   0.024699    0.48064  -0.561310  ...  0.009746 -0.008511
# ...           ...        ...        ...        ...  ...       ...       ...
# 190407   0.248050  -0.060009   -0.32178  -0.571270  ...  0.002598  0.003868
# 190408   0.217250  -0.067805   -0.31683  -0.570240  ...  0.007851 -0.003161
# 190409   0.103170  -0.109510   -0.31312  -0.570610  ...  0.044561 -0.018883
# 190410  -0.005755  -0.111670   -0.31178  -0.573860  ...  0.054995 -0.013549
# 190411  -0.034939  -0.121400   -0.30939  -0.575520  ...  0.075941 -0.020535
#
#         LC:MAG:X  LC:MAG:Y  LC:MAG:Z  LC:QUAT:1  LC:QUAT:2  LC:QUAT:3  \
# 0       -0.68310 -0.168230   0.15762    0.38733   0.670800   -0.37245
# 1       -0.69108 -0.162840   0.15532    0.38713   0.671070   -0.37212
# 2       -0.69206 -0.163670   0.15629    0.38749   0.670700   -0.37267
# 3       -0.68066 -0.165370   0.16288    0.39061   0.665770   -0.38739
# 4       -0.68840 -0.164040   0.16087    0.39083   0.665720   -0.38730
# ...          ...       ...       ...        ...        ...        ...
# 190407  -0.55780  0.032434  -0.39215    0.65462  -0.060946   -0.72977
# 190408  -0.55621  0.032931  -0.39206    0.65459  -0.061042   -0.72980
# 190409  -0.55837  0.032221  -0.39284    0.65485  -0.061101   -0.72960
# 190410  -0.55791  0.032417  -0.39399    0.65517  -0.061292   -0.72935
# 190411  -0.55744  0.032339  -0.39502    0.65567  -0.061399   -0.72895
#
#         LC:QUAT:4  targets
# 0         0.51115        0
# 1         0.51120        0
# 2         0.51101        0
# 3         0.50408        0
# 4         0.50405        0
# ...           ...      ...
# 190407    0.18760        0
# 190408    0.18757        0
# 190409    0.18739        0
# 190410    0.18717        0
# 190411    0.18696        0
#
# [190412 rows x 120 columns]
