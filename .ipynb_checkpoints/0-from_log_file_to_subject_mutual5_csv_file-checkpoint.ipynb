# %% [markdown]
# # Converting from .log file to csv file

# %%
import glob

# %%
dataset_path = r'D:\projec\Advanced pro1\sub'

# %%
f = glob.glob(dataset_path +'\*.log')

# %%
import numpy as np
import pandas as pd
import os

# %%
columns = ['ts1','ts2','RLA:ACC:X', 'RLA:ACC:Y', 'RLA:ACC:Z', 'RLA:GYR:X', 'RLA:GYR:Y', 'RLA:GYR:Z', 'RLA:MAG:X', 'RLA:MAG:Y', 'RLA:MAG:Z', 'RLA:QUAT:1', 'RLA:QUAT:2', 'RLA:QUAT:3', 'RLA:QUAT:4',
'RUA:ACC:X', 'RUA:ACC:Y', 'RUA:ACC:Z', 'RUA:GYR:X', 'RUA:GYR:Y', 'RUA:GYR:Z', 'RUA:MAG:X', 'RUA:MAG:Y', 'RUA:MAG:Z', 'RUA:QUAT:1', 'RUA:QUAT:2', 'RUA:QUAT:3', 'RUA:QUAT:4',
'BACK:ACC:X', 'BACK:ACC:Y', 'BACK:ACC:Z', 'BACK:GYR:X', 'BACK:GYR:Y', 'BACK:GYR:Z', 'BACK:MAG:X', 'BACK:MAG:Y', 'BACK:MAG:Z', 'BACK:QUAT:1', 'BACK:QUAT:2', 'BACK:QUAT:3', 'BACK:QUAT:4',
'LUA:ACC:X', 'LUA:ACC:Y', 'LUA:ACC:Z', 'LUA:GYR:X', 'LUA:GYR:Y', 'LUA:GYR:Z', 'LUA:MAG:X', 'LUA:MAG:Y', 'LUA:MAG:Z', 'LUA:QUAT:1', 'LUA:QUAT:2', 'LUA:QUAT:3', 'LUA:QUAT:4',
'LLA:ACC:X', 'LLA:ACC:Y', 'LLA:ACC:Z', 'LLA:GYR:X', 'LLA:GYR:Y', 'LLA:GYR:Z', 'LLA:MAG:X', 'LLA:MAG:Y', 'LLA:MAG:Z', 'LLA:QUAT:1', 'LLA:QUAT:2', 'LLA:QUAT:3', 'LLA:QUAT:4',
'RC:ACC:X', 'RC:ACC:Y', 'RC:ACC:Z', 'RC:GYR:X', 'RC:GYR:Y', 'RC:GYR:Z', 'RC:MAG:X', 'RC:MAG:Y', 'RC:MAG:Z', 'RC:QUAT:1', 'RC:QUAT:2', 'RC:QUAT:3', 'RC:QUAT:4',
'RT:ACC:X', 'RT:ACC:Y', 'RT:ACC:Z', 'RT:GYR:X', 'RT:GYR:Y', 'RT:GYR:Z', 'RT:MAG:X', 'RT:MAG:Y', 'RT:MAG:Z', 'RT:QUAT:1', 'RT:QUAT:2', 'RT:QUAT:3', 'RT:QUAT:4',
'LT:ACC:X', 'LT:ACC:Y', 'LT:ACC:Z', 'LT:GYR:X', 'LT:GYR:Y', 'LT:GYR:Z', 'LT:MAG:X', 'LT:MAG:Y', 'LT:MAG:Z', 'LT:QUAT:1', 'LT:QUAT:2', 'LT:QUAT:3', 'LT:QUAT:4',
'LC:ACC:X', 'LC:ACC:Y', 'LC:ACC:Z', 'LC:GYR:X', 'LC:GYR:Y', 'LC:GYR:Z', 'LC:MAG:X', 'LC:MAG:Y', 'LC:MAG:Z', 'LC:QUAT:1', 'LC:QUAT:2', 'LC:QUAT:3', 'LC:QUAT:4','targets']

# %%
parent_dir = r'D:\projec\proj'
path1 = os.path.join(parent_dir, "data_mutual5")

# %%
os.mkdir(path1)

# %%
List = [2,5,15]

# %%
for subject in List:
    file_path = dataset_path + '\subject{0}_mutual5.log'.format(subject)
    file = pd.read_csv(file_path,header=None, sep='\t',names=columns)
    for column in columns:
        file[column] = file[column].astype('float')
    file['targets'] = file['targets'].astype('int')
    
    file.to_csv(r"D:\projec\proj\data_mutual5\subject{0}_mutual5.csv".format(subject),header=None,sep='\t', index= False)

# %%
file = pd.read_csv(r"D:\projec\proj\data_mutual5\subject2_mutual5.csv",header=None, sep='\t',names=columns)

# %%
file
# Out:
#           ts1       ts2  RLA:ACC:X  RLA:ACC:Y  RLA:ACC:Z  RLA:GYR:X  \
# 0         0.0   20000.0   -7.44590  -2.779200    -5.3250   0.073510
# 1         0.0   40000.0   -7.62780  -2.334100    -5.3237   0.043406
# 2         0.0   60000.0   -7.87980  -2.458300    -5.6716  -0.023779
# 3         0.0   80000.0   -7.69420  -2.663100    -5.5500   0.038977
# 4         0.0  100000.0   -7.55150  -2.320600    -5.4974   0.112270
# ...       ...       ...        ...        ...        ...        ...
# 162043  383.0  140000.0   -0.81800  -0.352400    -9.8181   0.009271
# 162044  383.0  160000.0   -1.00730  -0.134790    -9.6904   0.025471
# 162045  383.0  180000.0   -0.95940  -0.043334    -9.6348  -0.023389
# 162046  383.0  200000.0   -0.90213  -0.023024    -9.7462  -0.025192
# 162047  383.0  220000.0   -0.92654  -0.013255    -9.7821  -0.023370
#
#         RLA:GYR:Y  RLA:GYR:Z  RLA:MAG:X  RLA:MAG:Y  ...  LC:GYR:Y  LC:GYR:Z  \
# 0       -0.040628  -0.011326   0.639280    0.26987  ...  0.024863 -0.017891
# 1       -0.045998   0.002895   0.638290    0.27658  ...  0.032666 -0.010817
# 2       -0.075254   0.014094   0.638810    0.27579  ...  0.048384 -0.015165
# 3       -0.040443   0.021820   0.641280    0.27260  ...  0.030950 -0.019653
# 4       -0.027922   0.015378   0.641500    0.27133  ...  0.041411 -0.012530
# ...           ...        ...        ...        ...  ...       ...       ...
# 162043   0.040566   0.059505   0.062617   -0.70293  ...  0.014283  0.008575
# 162044   0.036779   0.055834   0.062134   -0.70243  ...  0.000325  0.001454
# 162045   0.039017   0.036797   0.060736   -0.70390  ...  0.007277  0.014728
# 162046   0.041829   0.032051   0.060042   -0.70332  ...  0.007286  0.011199
# 162047   0.042776   0.023551   0.058025   -0.70548  ...  0.003792  0.009412
#
#         LC:MAG:X  LC:MAG:Y  LC:MAG:Z  LC:QUAT:1  LC:QUAT:2  LC:QUAT:3  \
# 0        0.68465  0.044095  -0.12604    0.73314    0.17474    0.60745
# 1        0.68148  0.047965  -0.12899    0.73295    0.17451    0.60774
# 2        0.68241  0.049989  -0.12840    0.73122    0.17789    0.60715
# 3        0.68427  0.047444  -0.12552    0.73125    0.17650    0.60686
# 4        0.68456  0.046110  -0.12500    0.73140    0.17554    0.60747
# ...          ...       ...       ...        ...        ...        ...
# 162043   0.72559  0.484260  -0.30917    0.22655    0.60215    0.33138
# 162044   0.72647  0.483630  -0.30782    0.22664    0.60212    0.33128
# 162045   0.72603  0.483550  -0.30850    0.22681    0.60218    0.33116
# 162046   0.72549  0.483180  -0.30880    0.22701    0.60221    0.33110
# 162047   0.72580  0.482990  -0.30800    0.22714    0.60224    0.33099
#
#         LC:QUAT:4  targets
# 0        -0.25094        0
# 1        -0.25096        0
# 2        -0.25504        0
# 3        -0.25659        0
# 4        -0.25538        0
# ...           ...      ...
# 162043   -0.69013        0
# 162044   -0.69017        0
# 162045   -0.69012        0
# 162046   -0.69006        0
# 162047   -0.69004        0
#
# [162048 rows x 120 columns]
