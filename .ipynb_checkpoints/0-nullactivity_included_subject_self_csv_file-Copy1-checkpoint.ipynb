# %% [markdown]
# # Converting from .log file to csv file

# %%
import glob

# %%
dataset_path = r'D:\projec\Advanced pro1\sub'

# %%
f = glob.glob(dataset_path +'\*.log')

# %%
import numpy as np
import pandas as pd
import os

# %%
columns = ['ts1','ts2','RLA:ACC:X', 'RLA:ACC:Y', 'RLA:ACC:Z', 'RLA:GYR:X', 'RLA:GYR:Y', 'RLA:GYR:Z', 'RLA:MAG:X', 'RLA:MAG:Y', 'RLA:MAG:Z', 'RLA:QUAT:1', 'RLA:QUAT:2', 'RLA:QUAT:3', 'RLA:QUAT:4',
'RUA:ACC:X', 'RUA:ACC:Y', 'RUA:ACC:Z', 'RUA:GYR:X', 'RUA:GYR:Y', 'RUA:GYR:Z', 'RUA:MAG:X', 'RUA:MAG:Y', 'RUA:MAG:Z', 'RUA:QUAT:1', 'RUA:QUAT:2', 'RUA:QUAT:3', 'RUA:QUAT:4',
'BACK:ACC:X', 'BACK:ACC:Y', 'BACK:ACC:Z', 'BACK:GYR:X', 'BACK:GYR:Y', 'BACK:GYR:Z', 'BACK:MAG:X', 'BACK:MAG:Y', 'BACK:MAG:Z', 'BACK:QUAT:1', 'BACK:QUAT:2', 'BACK:QUAT:3', 'BACK:QUAT:4',
'LUA:ACC:X', 'LUA:ACC:Y', 'LUA:ACC:Z', 'LUA:GYR:X', 'LUA:GYR:Y', 'LUA:GYR:Z', 'LUA:MAG:X', 'LUA:MAG:Y', 'LUA:MAG:Z', 'LUA:QUAT:1', 'LUA:QUAT:2', 'LUA:QUAT:3', 'LUA:QUAT:4',
'LLA:ACC:X', 'LLA:ACC:Y', 'LLA:ACC:Z', 'LLA:GYR:X', 'LLA:GYR:Y', 'LLA:GYR:Z', 'LLA:MAG:X', 'LLA:MAG:Y', 'LLA:MAG:Z', 'LLA:QUAT:1', 'LLA:QUAT:2', 'LLA:QUAT:3', 'LLA:QUAT:4',
'RC:ACC:X', 'RC:ACC:Y', 'RC:ACC:Z', 'RC:GYR:X', 'RC:GYR:Y', 'RC:GYR:Z', 'RC:MAG:X', 'RC:MAG:Y', 'RC:MAG:Z', 'RC:QUAT:1', 'RC:QUAT:2', 'RC:QUAT:3', 'RC:QUAT:4',
'RT:ACC:X', 'RT:ACC:Y', 'RT:ACC:Z', 'RT:GYR:X', 'RT:GYR:Y', 'RT:GYR:Z', 'RT:MAG:X', 'RT:MAG:Y', 'RT:MAG:Z', 'RT:QUAT:1', 'RT:QUAT:2', 'RT:QUAT:3', 'RT:QUAT:4',
'LT:ACC:X', 'LT:ACC:Y', 'LT:ACC:Z', 'LT:GYR:X', 'LT:GYR:Y', 'LT:GYR:Z', 'LT:MAG:X', 'LT:MAG:Y', 'LT:MAG:Z', 'LT:QUAT:1', 'LT:QUAT:2', 'LT:QUAT:3', 'LT:QUAT:4',
'LC:ACC:X', 'LC:ACC:Y', 'LC:ACC:Z', 'LC:GYR:X', 'LC:GYR:Y', 'LC:GYR:Z', 'LC:MAG:X', 'LC:MAG:Y', 'LC:MAG:Z', 'LC:QUAT:1', 'LC:QUAT:2', 'LC:QUAT:3', 'LC:QUAT:4','targets']

# %%
parent_dir = r'D:\projec\proj'
path1 = os.path.join(parent_dir, "data_self_null")

# %%
os.mkdir(path1)

# %%
for subject in range(1, 18):
    file_path = dataset_path + '\subject{0}_self.log'.format(subject)
    file = pd.read_csv(file_path,header=None, sep='\t',names=columns)
    for column in columns:
        file[column] = file[column].astype('float')
    file['targets'] = file['targets'].astype('int')
    
    file.to_csv(r"D:\projec\proj\data_self_null\subject{0}_self.csv".format(subject),header=None,sep='\t', index= False)

# %%
file = pd.read_csv(r"D:\projec\proj\data_self_null\subject1_self.csv",header=None, sep='\t',names=columns)

# %%
file
# Out:
#            ts1       ts2  RLA:ACC:X  RLA:ACC:Y  RLA:ACC:Z  RLA:GYR:X  \
# 0          0.0   20000.0    -9.7541     3.3232    -2.0692  -0.176470
# 1          0.0   40000.0    -9.2390     2.5249    -2.4857  -0.468040
# 2          0.0   60000.0    -9.1370     2.1923    -2.5635  -0.611980
# 3          0.0   80000.0    -8.9165     1.7496    -2.8630  -0.799670
# 4          0.0  100000.0    -9.5109     2.2566    -1.9086  -0.980100
# ...        ...       ...        ...        ...        ...        ...
# 166200  2168.0  460000.0    -8.6433     3.0724     4.0654  -0.033135
# 166201  2168.0  480000.0    -8.6425     2.8067     4.0258   0.039837
# 166202  2168.0  500000.0    -8.3272     3.0520     3.8609   0.017932
# 166203  2168.0  520000.0    -8.8844     3.0508     4.4933   0.065409
# 166204  2168.0  540000.0    -8.7099     3.1462     3.3179   0.123720
#
#         RLA:GYR:Y  RLA:GYR:Z  RLA:MAG:X  RLA:MAG:Y  ...  LC:GYR:Y  LC:GYR:Z  \
# 0        0.320610   0.312340    0.75924   -0.20178  ...  0.002563 -0.005975
# 1        0.277570   0.313910    0.75919   -0.19997  ...  0.011413  0.010268
# 2        0.232350   0.307370    0.75875   -0.20482  ...  0.006052  0.003046
# 3        0.206680   0.306060    0.75608   -0.21035  ... -0.006555  0.000386
# 4        0.117130   0.306060    0.75453   -0.21613  ... -0.004673 -0.003296
# ...           ...        ...        ...        ...  ...       ...       ...
# 166200   0.046678   0.026699    1.22740   -0.16385  ... -0.009379 -0.004550
# 166201   0.018532   0.001922    1.22900   -0.16275  ...  0.020284  0.006438
# 166202   0.027610  -0.011566    1.22660   -0.16144  ...  0.003330 -0.008150
# 166203  -0.038835   0.001757    1.22740   -0.16187  ...  0.006784  0.000927
# 166204   0.029916  -0.023482    1.22820   -0.16330  ...  0.010463 -0.006253
#
#         LC:MAG:X  LC:MAG:Y  LC:MAG:Z  LC:QUAT:1  LC:QUAT:2  LC:QUAT:3  \
# 0        0.71662  -0.15862 -0.021810    0.53729  -0.396920    0.56283
# 1        0.71901  -0.15333 -0.025614    0.53727  -0.397460    0.56264
# 2        0.71874  -0.15213 -0.023768    0.53613  -0.398730    0.56179
# 3        0.71754  -0.15606 -0.022152    0.53728  -0.400030    0.56073
# 4        0.71714  -0.15702 -0.020740    0.53759  -0.399730    0.56089
# ...          ...       ...       ...        ...        ...        ...
# 166200   0.77158   0.18403 -0.138440   -0.70991   0.074824   -0.69954
# 166201   0.77131   0.18376 -0.138180   -0.70978   0.074788   -0.69968
# 166202   0.77267   0.18196 -0.138360   -0.70976   0.074840   -0.69969
# 166203   0.77131   0.18348 -0.138190   -0.70973   0.074773   -0.69972
# 166204   0.77049   0.18291 -0.135810   -0.70968   0.074706   -0.69978
#
#         LC:QUAT:4  targets
# 0        0.486830        0
# 1        0.486630        0
# 2        0.487820        0
# 3        0.486720        0
# 4        0.486440        0
# ...           ...      ...
# 166200   0.032902        0
# 166201   0.032807        0
# 166202   0.032830        0
# 166203   0.032840        0
# 166204   0.032957        0
#
# [166205 rows x 120 columns]
