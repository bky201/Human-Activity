# %% [markdown]
# # Subject wise distribution of dataset -Accelerometer

# %%
import glob
import pandas as pd
import numpy as np
import os, sys
import collections
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors.nearest_centroid import NearestCentroid
from sklearn.tree import DecisionTreeClassifier


from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier 
from sklearn.decomposition import PCA
# Out:
# C:\Users\BKY\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.neighbors.nearest_centroid module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from numba.typed import List
from numba import jit, njit, vectorize

# %%
sample_rate = 50  # number of observation per second based on dataset documentation(150 samples in 3 second)

sliding_size = int((1/3) * sample_rate)  # number of skipped datapoints to start next window
print(sliding_size)
# Out:
# 16

# %% [markdown]
# # Feature sets

# %%
@njit()
def mean_crossing_rate(col):
    # col = np.array(values)
    normalized = col - col.mean()  # to make elements of array possitive or negetive
    return ((normalized[:-1] * col[1:]) < 0).sum()  # Zero-Crossing_rate

@njit()
def iqr(window):  # inter-quartile range
    Q1 = np.median(window[:len(window)//2])  # First quartile (Q1) 
    Q3 = np.median(window[len(window)//2:])  # Third quartile (Q3) 
    IQR = Q3 - Q1 # Interquartile range (IQR) 
    return(IQR) 
@njit()
def calc_sma_for_window(data):
    return np.sum(data) / len(data)  
@njit()
def get_min(x):
    m = np.min(x)
    return m
@njit()
def get_max(x):
    m = np.max(x)
    return m
@njit()
def get_mean(x):
    m = np.mean(x)
    return m
@njit()
def get_var(x):
    m = np.var(x)
    return m
@njit()
def get_mean(x):
    m = np.mean(x)
    return m
@njit()
def get_sum(x):
    m = x.sum()
    return m 
@njit()
def get_median(x):
    m = np.median(x)
    return m 
@njit()
def get_std(x):
    m = np.median(x)
    return m

# %%
def Energy(frame):
    return sum( [ abs(x)**2 for x in frame ] ) / len(frame)

# %%
def Features(window):# mean, std,max,min and zero-crossing-rate
    win = np.array(window[:-1])
    features = []
    
    features.append(get_mean(win))
    features.append(get_median(win))
    features.append(get_var(win))
    features.append(get_std(win))
    features.append(get_min(win))
    features.append(get_max(win))
    features.append(get_sum(win))
    mean_crossing = [mean_crossing_rate(window.iloc[:, i].values) for i in range(window.shape[1] - 1)]
    features.append(np.array(mean_crossing))
    IQR = iqr(win)
    features.append(np.array(IQR))
    energy_measure = Energy(win)
    features.append(np.array(energy_measure))
 

    features = np.hstack(features).tolist()

    label = window.iloc[:, -1].mode()[0]  ## select the most frequent label as the label of the window
    features.append(label)
    return features

# %%
def windowing_dataset(dataset, win_size, feature_extraction_function, subject_id, overlap=False):
    windowed_dataset = []
    win_count = 0
    if overlap:
        step_size = sliding_size  # for Overlapping technique
    else:
        step_size = win_size  # for Non-overlapping technique

    for index in range(0, dataset.shape[0], step_size):
        start = index
        end = start + win_size
        # to assure all of windows are equal in size
        if (end <= dataset.shape[0]):
            window = dataset.iloc[start:end, :].reset_index(drop=True)
            win_count = win_count + 1
            features = feature_extraction_function(window)

            windowed_dataset.append(features)

    final = pd.DataFrame(windowed_dataset)
    final.insert(0, 'group', subject_id)  # to use in Subject CV
    return final

# %%
def Preprocessing(dataset_path, overlapping):
    feature_function = Features
    win_size = 3
    #for win_size in win_sizes:
    print("Start for win size {}".format(win_size))
    datapoints_per_window = int(win_size * sample_rate)

    #for feature_function in features_functions:

    print(feature_function.__name__)

    windowed_dataset = []

    for subject in range(1,18):
        file_path = dataset_path + '\subject{0}_ideal.csv'.format(subject)
        acc_cols = []
        for i in range(2, 117, 13):# indices of accelarations
            indices = list(range(i, i + 3))
            acc_cols.extend(indices)

        acc_cols.append(119)  # label index

        tmp_db = pd.read_csv(file_path, header=None, usecols=acc_cols, sep='\t')
        tmp_db.columns = list(range(tmp_db.shape[1]))  # re-index the columns

        transformed_db = windowing_dataset(tmp_db, datapoints_per_window, feature_function, subject,
                                                   overlap=overlapping)

        windowed_dataset.append(transformed_db)

    final_dataset = pd.DataFrame()
    print("Features")
    final_dataset = final_dataset.append(windowed_dataset, ignore_index=True)
    return final_dataset

# %%
def subject_cross_validation(X, Y, groups, classifier):
    f1 = []
    logo = LeaveOneGroupOut()
    i = 0
    for train_index, test_index in logo.split(X, Y, groups=groups):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = Y[train_index], Y[test_index]
        i += 1
        classifier.fit(X_train, y_train)

        y_pred = classifier.predict(X_test)
        f = f1_score(y_true=y_test, y_pred=y_pred, average='micro')
        
        print(classifier,' Model-',i ,' -',' f1 score: ', f)
       
        f1.append(f)
    return np.mean(f1)

# %%
# cv_strategy can be iid or sbj for k-fold cv and subject cv respectively

def apply_classifiers(dataset, models, cv_strategy):
    results = dict()
    win_size = float(3)
    print('window_size = ', win_size,' sec')

    dataset = dataset
    groups = dataset['group']
    X = dataset.iloc[:, 1:-1]
    X = np.array(X)
    
    pca = PCA(n_components=30, random_state = 42)
    pca.fit(X)
    X = pca.transform(X)
    
    Y = dataset.iloc[:, -1].values
    Y = np.array(Y)

    for model_name, model in models.items():
        f1 = 0
        i = 0
        #if cv_strategy == 'sbj':

        f1 = subject_cross_validation(X, Y, groups, model)

        #else:

        #f1 = cross_val_score(estimator=model, X=X, y=Y,cv=KFold(n_splits=10, shuffle=True, random_state=1), scoring='f1_micro',n_jobs=-1).mean()

        if win_size in results:
            results[win_size].append(f1)
        else:
            results[win_size] = [f1]

        # export as csv file

        results = collections.OrderedDict(sorted(results.items()))

        final = []
        col = list(models.keys())
        col.insert(0, "window-size")
        final.append(col)
        for k, v in results.items():
            tmp = []
            tmp.append([k])
            tmp.append(v)
            flattened = [val for sublist in tmp for val in sublist]
            final.append(flattened)
    final = pd.DataFrame(final)   
    return final

# %%
models = {'DT': DecisionTreeClassifier(criterion='entropy'), 'NB': GaussianNB(),
          'NCC': NearestCentroid(), "KNN": KNeighborsClassifier(n_neighbors=3),
          'RF': RandomForestClassifier(n_estimators=40,random_state=42, n_jobs=-1)}

# %%
# %%time
dataset_csv_path = r"D:\projec\proj\data"

overlapping = 1

df = Preprocessing(dataset_path=dataset_csv_path, overlapping=bool(int(overlapping)))

df.head(10)
# Out:
# Start for win size 3
# Features
# Features
# Wall time: 5min 20s
#    group         0        1          2        3       4       5             6  \
# 0      1 -1.633620 -1.00435  30.094853 -1.00435 -13.572  13.123  -6815.463652
# 1      1 -1.639097 -1.06545  30.104036 -1.06545 -13.572  13.123  -6838.311812
# 2      1 -1.661861 -1.20775  30.313215 -1.20775 -13.572  13.123  -6933.284960
# 3      1 -1.715638 -1.24765  29.776745 -1.24765 -13.547  10.304  -7157.641101
# 4      1 -1.762650 -1.17900  29.704331 -1.17900 -13.547  12.127  -7353.774895
# 5      1 -1.867453 -1.14215  30.132488 -1.14215 -16.693  13.038  -7791.014918
# 6      1 -1.979606 -1.18770  29.463555 -1.18770 -16.693  13.038  -8258.915145
# 7      1 -2.125250 -1.32565  29.300628 -1.32565 -16.693  18.240  -8866.543711
# 8      1 -2.284407 -1.34015  29.472833 -1.34015 -18.348  18.240  -9530.548005
# 9      1 -2.442704 -1.37980  28.318927 -1.37980 -18.348  18.240 -10190.963090
#
#       7     8  ...        54        55         56        57        58  \
# 0  51.0  73.0  ...  2.593908  3.921385  91.174770  4.905180  6.950782
# 1  54.0  82.0  ...  2.855557  4.288218  89.176574  4.811995  6.125328
# 2  55.0  84.0  ...  3.179011  4.984253  91.011443  5.429592  7.113794
# 3  27.0  90.0  ...  3.262519  4.449573  90.943000  5.761267  8.118373
# 4  22.0  95.0  ...  2.882481  3.759509  89.543313  5.228089  7.611502
# 5  37.0  90.0  ...  3.190035  3.793951  92.778907  5.139430  8.719024
# 6  42.0  76.0  ...  3.413811  3.411228  92.333098  5.080037  7.986029
# 7  47.0  54.0  ...  3.959646  5.454866  90.466802  4.931867  7.836691
# 8  51.0  56.0  ...  4.767428  5.541494  95.926050  5.450808  9.022392
# 9  53.0  58.0  ...  4.336226  5.366557  91.578048  4.842937  9.462464
#
#            59        60         61   62  63
# 0  102.991179  2.137176  10.651568  1.0   1
# 1  105.046067  2.107242   9.677228  1.0   1
# 2  102.195931  2.257098   8.337835  1.0   1
# 3  101.553044  2.343028   6.122427  1.0   1
# 4  102.890095  2.218564   7.288485  1.0   1
# 5  104.971318  2.267715  10.694123  1.0   1
# 6  103.833455  2.306007  10.382769  1.0   1
# 7  105.831842  2.330283   9.540168  1.0   1
# 8  102.423261  2.511480   8.572841  1.0   1
# 9  106.798786  2.395293  10.053509  1.0   1
#
# [10 rows x 65 columns]

# %%
df.shape
# Out:
# (44339, 65)

# %%
# %%time
dataset = df

apply_classifiers(dataset=dataset, models=models, cv_strategy='sbj')
# Out:
# window_size =  3.0  sec
# DecisionTreeClassifier(criterion='entropy')  Model- 1  -  f1 score:  0.7706293706293706
# DecisionTreeClassifier(criterion='entropy')  Model- 2  -  f1 score:  0.8879097638350371
# DecisionTreeClassifier(criterion='entropy')  Model- 3  -  f1 score:  0.7216
# DecisionTreeClassifier(criterion='entropy')  Model- 4  -  f1 score:  0.8485543827443781
# DecisionTreeClassifier(criterion='entropy')  Model- 5  -  f1 score:  0.7310344827586208
# DecisionTreeClassifier(criterion='entropy')  Model- 6  -  f1 score:  0.8066666666666665
# DecisionTreeClassifier(criterion='entropy')  Model- 7  -  f1 score:  0.6952908587257618
# DecisionTreeClassifier(criterion='entropy')  Model- 8  -  f1 score:  0.837173579109063
# DecisionTreeClassifier(criterion='entropy')  Model- 9  -  f1 score:  0.802051282051282
# DecisionTreeClassifier(criterion='entropy')  Model- 10  -  f1 score:  0.697507681802663
# DecisionTreeClassifier(criterion='entropy')  Model- 11  -  f1 score:  0.7653125
# DecisionTreeClassifier(criterion='entropy')  Model- 12  -  f1 score:  0.8404522613065326
# DecisionTreeClassifier(criterion='entropy')  Model- 13  -  f1 score:  0.6720293536550945
# DecisionTreeClassifier(criterion='entropy')  Model- 14  -  f1 score:  0.6937697993664202
# DecisionTreeClassifier(criterion='entropy')  Model- 15  -  f1 score:  0.7938501515807709
# DecisionTreeClassifier(criterion='entropy')  Model- 16  -  f1 score:  0.7205989773557342
# DecisionTreeClassifier(criterion='entropy')  Model- 17  -  f1 score:  0.7862305058957778
# GaussianNB()  Model- 1  -  f1 score:  0.867132867132867
# GaussianNB()  Model- 2  -  f1 score:  0.9626365879450124
# GaussianNB()  Model- 3  -  f1 score:  0.8332
# GaussianNB()  Model- 4  -  f1 score:  0.9293253786140432
# GaussianNB()  Model- 5  -  f1 score:  0.8937931034482759
# GaussianNB()  Model- 6  -  f1 score:  0.9105555555555556
# GaussianNB()  Model- 7  -  f1 score:  0.8088642659279779
# GaussianNB()  Model- 8  -  f1 score:  0.8506144393241167
# GaussianNB()  Model- 9  -  f1 score:  0.9367521367521368
# GaussianNB()  Model- 10  -  f1 score:  0.8934790030727211
# GaussianNB()  Model- 11  -  f1 score:  0.9271875
# GaussianNB()  Model- 12  -  f1 score:  0.8555276381909548
# GaussianNB()  Model- 13  -  f1 score:  0.8044030482641829
# GaussianNB()  Model- 14  -  f1 score:  0.8486448433650123
# GaussianNB()  Model- 15  -  f1 score:  0.9055868341273279
# GaussianNB()  Model- 16  -  f1 score:  0.8758217677136596
# GaussianNB()  Model- 17  -  f1 score:  0.896918980600989
# NearestCentroid()  Model- 1  -  f1 score:  0.20349650349650347
# NearestCentroid()  Model- 2  -  f1 score:  0.37046175537539655
# NearestCentroid()  Model- 3  -  f1 score:  0.148
# NearestCentroid()  Model- 4  -  f1 score:  0.3166590178981184
# NearestCentroid()  Model- 5  -  f1 score:  0.3117241379310345
# NearestCentroid()  Model- 6  -  f1 score:  0.4222222222222222
# NearestCentroid()  Model- 7  -  f1 score:  0.7922437673130194
# NearestCentroid()  Model- 8  -  f1 score:  0.2903225806451613
# NearestCentroid()  Model- 9  -  f1 score:  0.467008547008547
# NearestCentroid()  Model- 10  -  f1 score:  0.15670877432570843
# NearestCentroid()  Model- 11  -  f1 score:  0.4225
# NearestCentroid()  Model- 12  -  f1 score:  0.355213567839196
# NearestCentroid()  Model- 13  -  f1 score:  0.3302286198137172
# NearestCentroid()  Model- 14  -  f1 score:  0.43189017951425557
# NearestCentroid()  Model- 15  -  f1 score:  0.13945430922477262
# NearestCentroid()  Model- 16  -  f1 score:  0.21329437545653762
# NearestCentroid()  Model- 17  -  f1 score:  0.22518067706352224
# KNeighborsClassifier(n_neighbors=3)  Model- 1  -  f1 score:  0.8527972027972028
# KNeighborsClassifier(n_neighbors=3)  Model- 2  -  f1 score:  0.9224532957349313
# KNeighborsClassifier(n_neighbors=3)  Model- 3  -  f1 score:  0.8447999999999999
# KNeighborsClassifier(n_neighbors=3)  Model- 4  -  f1 score:  0.9311610830656264
# KNeighborsClassifier(n_neighbors=3)  Model- 5  -  f1 score:  0.8772413793103448
# KNeighborsClassifier(n_neighbors=3)  Model- 6  -  f1 score:  0.915
# KNeighborsClassifier(n_neighbors=3)  Model- 7  -  f1 score:  0.9224376731301939
# KNeighborsClassifier(n_neighbors=3)  Model- 8  -  f1 score:  0.9005376344086021
# KNeighborsClassifier(n_neighbors=3)  Model- 9  -  f1 score:  0.8471794871794872
# KNeighborsClassifier(n_neighbors=3)  Model- 10  -  f1 score:  0.7975418231478321
# KNeighborsClassifier(n_neighbors=3)  Model- 11  -  f1 score:  0.87625
# KNeighborsClassifier(n_neighbors=3)  Model- 12  -  f1 score:  0.9261934673366834
# KNeighborsClassifier(n_neighbors=3)  Model- 13  -  f1 score:  0.9085520745131245
# KNeighborsClassifier(n_neighbors=3)  Model- 14  -  f1 score:  0.9035550862372405
# KNeighborsClassifier(n_neighbors=3)  Model- 15  -  f1 score:  0.8349935036812473
# KNeighborsClassifier(n_neighbors=3)  Model- 16  -  f1 score:  0.8907962016070125
# KNeighborsClassifier(n_neighbors=3)  Model- 17  -  f1 score:  0.8896918980600989
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 1  -  f1 score:  0.8325174825174825
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 2  -  f1 score:  0.9615791328868523
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 3  -  f1 score:  0.8924
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 4  -  f1 score:  0.9398806792106471
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 5  -  f1 score:  0.9482758620689655
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 6  -  f1 score:  0.965
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 7  -  f1 score:  0.9750692520775623
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 8  -  f1 score:  0.9116743471582182
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 9  -  f1 score:  0.9347008547008547
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 10  -  f1 score:  0.8692386480027313
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 11  -  f1 score:  0.9253125
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 12  -  f1 score:  0.9462939698492462
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 13  -  f1 score:  0.8899237933954276
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 14  -  f1 score:  0.9130587821189723
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 15  -  f1 score:  0.8869640537029017
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 16  -  f1 score:  0.9035792549306063
# RandomForestClassifier(n_estimators=40, n_jobs=-1, random_state=42)  Model- 17  -  f1 score:  0.9395207303157094
# Wall time: 6min 56s
#              0         1         2         3         4         5
# 0  window-size        DT        NB       NCC       KNN        RF
# 1            3  0.768862  0.882379  0.329212  0.884775  0.919705

# %%
x = ['DT', 'NB', 'NCC', 'KNN','RF']
accuracy = [0.768,0.882,0.329,0.884,0.919]

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, accuracy, color='brown')
plt.xlabel("Model")
plt.ylabel("accuracy")
plt.title("ACC-SENSOR ACCURACY SUBJECT WISE")

plt.xticks(x_pos, x)

plt.show()
