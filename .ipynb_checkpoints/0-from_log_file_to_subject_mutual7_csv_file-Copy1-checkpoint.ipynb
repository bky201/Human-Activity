# %% [markdown]
# # Converting from .log file to csv file

# %%
import glob

# %%
dataset_path = r'D:\projec\Advanced pro1\sub'

# %%
f = glob.glob(dataset_path +'\*.log')

# %%
import numpy as np
import pandas as pd
import os

# %%
columns = ['ts1','ts2','RLA:ACC:X', 'RLA:ACC:Y', 'RLA:ACC:Z', 'RLA:GYR:X', 'RLA:GYR:Y', 'RLA:GYR:Z', 'RLA:MAG:X', 'RLA:MAG:Y', 'RLA:MAG:Z', 'RLA:QUAT:1', 'RLA:QUAT:2', 'RLA:QUAT:3', 'RLA:QUAT:4',
'RUA:ACC:X', 'RUA:ACC:Y', 'RUA:ACC:Z', 'RUA:GYR:X', 'RUA:GYR:Y', 'RUA:GYR:Z', 'RUA:MAG:X', 'RUA:MAG:Y', 'RUA:MAG:Z', 'RUA:QUAT:1', 'RUA:QUAT:2', 'RUA:QUAT:3', 'RUA:QUAT:4',
'BACK:ACC:X', 'BACK:ACC:Y', 'BACK:ACC:Z', 'BACK:GYR:X', 'BACK:GYR:Y', 'BACK:GYR:Z', 'BACK:MAG:X', 'BACK:MAG:Y', 'BACK:MAG:Z', 'BACK:QUAT:1', 'BACK:QUAT:2', 'BACK:QUAT:3', 'BACK:QUAT:4',
'LUA:ACC:X', 'LUA:ACC:Y', 'LUA:ACC:Z', 'LUA:GYR:X', 'LUA:GYR:Y', 'LUA:GYR:Z', 'LUA:MAG:X', 'LUA:MAG:Y', 'LUA:MAG:Z', 'LUA:QUAT:1', 'LUA:QUAT:2', 'LUA:QUAT:3', 'LUA:QUAT:4',
'LLA:ACC:X', 'LLA:ACC:Y', 'LLA:ACC:Z', 'LLA:GYR:X', 'LLA:GYR:Y', 'LLA:GYR:Z', 'LLA:MAG:X', 'LLA:MAG:Y', 'LLA:MAG:Z', 'LLA:QUAT:1', 'LLA:QUAT:2', 'LLA:QUAT:3', 'LLA:QUAT:4',
'RC:ACC:X', 'RC:ACC:Y', 'RC:ACC:Z', 'RC:GYR:X', 'RC:GYR:Y', 'RC:GYR:Z', 'RC:MAG:X', 'RC:MAG:Y', 'RC:MAG:Z', 'RC:QUAT:1', 'RC:QUAT:2', 'RC:QUAT:3', 'RC:QUAT:4',
'RT:ACC:X', 'RT:ACC:Y', 'RT:ACC:Z', 'RT:GYR:X', 'RT:GYR:Y', 'RT:GYR:Z', 'RT:MAG:X', 'RT:MAG:Y', 'RT:MAG:Z', 'RT:QUAT:1', 'RT:QUAT:2', 'RT:QUAT:3', 'RT:QUAT:4',
'LT:ACC:X', 'LT:ACC:Y', 'LT:ACC:Z', 'LT:GYR:X', 'LT:GYR:Y', 'LT:GYR:Z', 'LT:MAG:X', 'LT:MAG:Y', 'LT:MAG:Z', 'LT:QUAT:1', 'LT:QUAT:2', 'LT:QUAT:3', 'LT:QUAT:4',
'LC:ACC:X', 'LC:ACC:Y', 'LC:ACC:Z', 'LC:GYR:X', 'LC:GYR:Y', 'LC:GYR:Z', 'LC:MAG:X', 'LC:MAG:Y', 'LC:MAG:Z', 'LC:QUAT:1', 'LC:QUAT:2', 'LC:QUAT:3', 'LC:QUAT:4','targets']

# %%
parent_dir = r'D:\projec\proj'
path1 = os.path.join(parent_dir, "data_mutual7")

# %%
os.mkdir(path1)

# %%
List = [2,5,15]

# %%
for subject in List:
    file_path = dataset_path + '\subject{0}_mutual7.log'.format(subject)
    file = pd.read_csv(file_path,header=None, sep='\t',names=columns)
    for column in columns:
        file[column] = file[column].astype('float')
    file['targets'] = file['targets'].astype('int')
    
    file.to_csv(r"D:\projec\proj\data_mutual7\subject{0}_mutual7.csv".format(subject),header=None,sep='\t', index= False)

# %%
file = pd.read_csv(r"D:\projec\proj\data_mutual7\subject2_mutual7.csv",header=None, sep='\t',names=columns)

# %%
file
# Out:
#           ts1       ts2  RLA:ACC:X  RLA:ACC:Y  RLA:ACC:Z  RLA:GYR:X  \
# 0         0.0   20000.0    -9.4978    0.41091     2.4947  -0.019317
# 1         0.0   40000.0    -9.5093    0.29313     2.4368  -0.003000
# 2         0.0   60000.0    -9.4780    0.27664     2.4008   0.009640
# 3         0.0   80000.0    -9.5051    0.42767     2.5065   0.004259
# 4         0.0  100000.0    -9.4754    0.34333     2.5220  -0.011053
# ...       ...       ...        ...        ...        ...        ...
# 87750  1755.0   20000.0     3.3565    5.07200     4.5462  -0.261060
# 87751  1755.0   40000.0     3.4385    4.67700     4.9097  -0.253370
# 87752  1755.0   60000.0     4.1986    5.07170     4.8351  -0.229720
# 87753  1755.0   80000.0     4.7426    5.18900     4.6211  -0.169740
# 87754  1755.0  100000.0     4.9455    5.58160     5.1738  -0.115310
#
#        RLA:GYR:Y  RLA:GYR:Z  RLA:MAG:X  RLA:MAG:Y  ...  LC:GYR:Y  LC:GYR:Z  \
# 0      -0.007285   0.004846    1.20840    0.33852  ...  0.002473 -0.011899
# 1      -0.011094  -0.000814    1.20930    0.34424  ...  0.013830 -0.018914
# 2      -0.018599  -0.005553    1.20780    0.34444  ...  0.001613 -0.020732
# 3      -0.001847  -0.002652    1.21010    0.33985  ...  0.007678 -0.004817
# 4       0.005673  -0.000790    1.21040    0.33894  ...  0.003347 -0.013660
# ...          ...        ...        ...        ...  ...       ...       ...
# 87750  -0.777030   0.022774   -0.14083   -0.38653  ... -0.630880  0.580600
# 87751  -0.732560   0.029478   -0.14998   -0.38237  ... -0.804520  0.713650
# 87752  -0.691940   0.033201   -0.15875   -0.37902  ... -1.018900  0.890760
# 87753  -0.648720   0.025708   -0.16704   -0.37838  ... -1.264800  1.137500
# 87754  -0.609270   0.052407   -0.17491   -0.37581  ... -1.553700  1.410500
#
#        LC:MAG:X  LC:MAG:Y  LC:MAG:Z  LC:QUAT:1  LC:QUAT:2  LC:QUAT:3  \
# 0       0.71600  -0.42958  0.255590    0.59224   -0.38217    0.61306
# 1       0.71738  -0.42835  0.252420    0.59228   -0.38234    0.61302
# 2       0.71709  -0.42831  0.251890    0.59123   -0.38438    0.61176
# 3       0.71691  -0.42918  0.253170    0.59159   -0.38436    0.61144
# 4       0.71825  -0.42845  0.253770    0.59182   -0.38412    0.61162
# ...         ...       ...       ...        ...        ...        ...
# 87750   0.58130  -0.42701  0.045649    0.39373   -0.56000    0.45358
# 87751   0.57539  -0.43386  0.029252    0.39102   -0.55313    0.45230
# 87752   0.56901  -0.44158  0.016231    0.38886   -0.54414    0.45159
# 87753   0.56068  -0.45430  0.005275    0.38730   -0.53128    0.45242
# 87754   0.54786  -0.46720 -0.010253    0.38569   -0.51536    0.45376
#
#        LC:QUAT:4  targets
# 0        0.35687        0
# 1        0.35669        0
# 2        0.35840        0
# 3        0.35838        0
# 4        0.35795        0
# ...          ...      ...
# 87750    0.57065        0
# 87751    0.58015        0
# 87752    0.59056        0
# 87753    0.60254        0
# 87754    0.61624        0
#
# [87755 rows x 120 columns]
